# %% [markdown]
# # Capstone 2: Data Wrangling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import math

# %%
CURR_DIR = os.path.dirname(os.path.realpath('__file__'))
filenames = glob.glob(os.path.join(CURR_DIR, 'F500_2019/*.csv'))

data = []
for csv in filenames:
    frame = pd.read_csv(csv)
    frame['Ticker'] = os.path.basename(csv).replace('EOD-', '').replace('.csv','')
    data.append(frame)

# %%
bigframe = pd.concat(data, ignore_index=True)
bigframe['Datetime'] = pd.to_datetime(bigframe['Date'])
bigframe.head()
# Out:
#          Date    Open    High       Low   Close      Volume  Dividend  Split  \
# 0  2020-05-08  305.64  310.35  304.2900  310.13  33511985.0      0.82    1.0
# 1  2020-05-07  303.22  305.17  301.9700  303.74  28803764.0      0.00    1.0
# 2  2020-05-06  300.46  303.24  298.8700  300.63  35583438.0      0.00    1.0
# 3  2020-05-05  295.06  301.00  294.4600  297.56  36937795.0      0.00    1.0
# 4  2020-05-04  289.17  293.69  286.3172  293.16  33391986.0      0.00    1.0
#
#      Adj_Open    Adj_High     Adj_Low   Adj_Close  Adj_Volume Ticker  \
# 0  305.640000  310.350000  304.290000  310.130000  33511985.0   AAPL
# 1  302.420385  304.365242  301.173681  302.939013  28803764.0   AAPL
# 2  299.667663  302.440332  298.081856  299.837215  35583438.0   AAPL
# 3  294.281903  300.206239  293.683485  296.775311  36937795.0   AAPL
# 4  288.407436  292.915516  285.562159  292.386914  33391986.0   AAPL
#
#     Datetime
# 0 2020-05-08
# 1 2020-05-07
# 2 2020-05-06
# 3 2020-05-05
# 4 2020-05-04

# %%
bigframe.tail()
# Out:
#               Date   Open   High    Low  Close   Volume  Dividend  Split  \
# 372120  1970-01-08  62.50  63.00  62.25  62.62  33600.0       0.0    1.0
# 372121  1970-01-07  62.87  62.87  62.38  62.50  28700.0       0.0    1.0
# 372122  1970-01-06  63.00  63.13  62.25  62.87  38500.0       0.0    1.0
# 372123  1970-01-05  62.00  63.00  61.87  63.00  58800.0       0.0    1.0
# 372124  1970-01-02  61.75  62.00  61.62  62.00  36700.0       0.0    1.0
#
#         Adj_Open  Adj_High   Adj_Low  Adj_Close  Adj_Volume Ticker   Datetime
# 372120  0.677149  0.682566  0.674440   0.678449   1075200.0    XOM 1970-01-08
# 372121  0.681158  0.681158  0.675849   0.677149    918400.0    XOM 1970-01-07
# 372122  0.682566  0.683974  0.674440   0.681158   1232000.0    XOM 1970-01-06
# 372123  0.671732  0.682566  0.670323   0.682566   1881600.0    XOM 1970-01-05
# 372124  0.669023  0.671732  0.667615   0.671732   1174400.0    XOM 1970-01-02

# %%
bigframe.dtypes
# Out:
# Date                  object
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume               float64
# Dividend             float64
# Split                float64
# Adj_Open             float64
# Adj_High             float64
# Adj_Low              float64
# Adj_Close            float64
# Adj_Volume           float64
# Ticker                object
# Datetime      datetime64[ns]
# dtype: object

# %%
bigframe.info
# Out:
# <bound method DataFrame.info of               Date    Open    High       Low   Close      Volume  Dividend  \
# 0       2020-05-08  305.64  310.35  304.2900  310.13  33511985.0      0.82
# 1       2020-05-07  303.22  305.17  301.9700  303.74  28803764.0      0.00
# 2       2020-05-06  300.46  303.24  298.8700  300.63  35583438.0      0.00
# 3       2020-05-05  295.06  301.00  294.4600  297.56  36937795.0      0.00
# 4       2020-05-04  289.17  293.69  286.3172  293.16  33391986.0      0.00
# ...            ...     ...     ...       ...     ...         ...       ...
# 372120  1970-01-08   62.50   63.00   62.2500   62.62     33600.0      0.00
# 372121  1970-01-07   62.87   62.87   62.3800   62.50     28700.0      0.00
# 372122  1970-01-06   63.00   63.13   62.2500   62.87     38500.0      0.00
# 372123  1970-01-05   62.00   63.00   61.8700   63.00     58800.0      0.00
# 372124  1970-01-02   61.75   62.00   61.6200   62.00     36700.0      0.00
#
#         Split    Adj_Open    Adj_High     Adj_Low   Adj_Close  Adj_Volume  \
# 0         1.0  305.640000  310.350000  304.290000  310.130000  33511985.0
# 1         1.0  302.420385  304.365242  301.173681  302.939013  28803764.0
# 2         1.0  299.667663  302.440332  298.081856  299.837215  35583438.0
# 3         1.0  294.281903  300.206239  293.683485  296.775311  36937795.0
# 4         1.0  288.407436  292.915516  285.562159  292.386914  33391986.0
# ...       ...         ...         ...         ...         ...         ...
# 372120    1.0    0.677149    0.682566    0.674440    0.678449   1075200.0
# 372121    1.0    0.681158    0.681158    0.675849    0.677149    918400.0
# 372122    1.0    0.682566    0.683974    0.674440    0.681158   1232000.0
# 372123    1.0    0.671732    0.682566    0.670323    0.682566   1881600.0
# 372124    1.0    0.669023    0.671732    0.667615    0.671732   1174400.0
#
#        Ticker   Datetime
# 0        AAPL 2020-05-08
# 1        AAPL 2020-05-07
# 2        AAPL 2020-05-06
# 3        AAPL 2020-05-05
# 4        AAPL 2020-05-04
# ...       ...        ...
# 372120    XOM 1970-01-08
# 372121    XOM 1970-01-07
# 372122    XOM 1970-01-06
# 372123    XOM 1970-01-05
# 372124    XOM 1970-01-02
#
# [372125 rows x 15 columns]>

# %%
bigframe.isnull().values.any()
# Out:
# False

# %%
bigframe[bigframe['Ticker'] == 'AAPL'].T
# Out:
#                            0                    1                    2     \
# Date                 2020-05-08           2020-05-07           2020-05-06
# Open                     305.64               303.22               300.46
# High                     310.35               305.17               303.24
# Low                      304.29               301.97               298.87
# Close                    310.13               303.74               300.63
# Volume               3.3512e+07          2.88038e+07          3.55834e+07
# Dividend                   0.82                    0                    0
# Split                         1                    1                    1
# Adj_Open                 305.64               302.42              299.668
# Adj_High                 310.35              304.365               302.44
# Adj_Low                  304.29              301.174              298.082
# Adj_Close                310.13              302.939              299.837
# Adj_Volume           3.3512e+07          2.88038e+07          3.55834e+07
# Ticker                     AAPL                 AAPL                 AAPL
# Datetime    2020-05-08 00:00:00  2020-05-07 00:00:00  2020-05-06 00:00:00
#
#                            3                    4                    5     \
# Date                 2020-05-05           2020-05-04           2020-05-01
# Open                     295.06               289.17               286.25
# High                        301               293.69                  299
# Low                      294.46              286.317               285.85
# Close                    297.56               293.16               289.07
# Volume              3.69378e+07           3.3392e+07          6.01542e+07
# Dividend                      0                    0                    0
# Split                         1                    1                    1
# Adj_Open                294.282              288.407              285.495
# Adj_High                300.206              292.916              298.212
# Adj_Low                 293.683              285.562              285.096
# Adj_Close               296.775              292.387              288.308
# Adj_Volume          3.69378e+07           3.3392e+07          6.01542e+07
# Ticker                     AAPL                 AAPL                 AAPL
# Datetime    2020-05-05 00:00:00  2020-05-04 00:00:00  2020-05-01 00:00:00
#
#                            6                    7                    8     \
# Date                 2020-04-30           2020-04-29           2020-04-28
# Open                     289.96               284.73               285.08
# High                     294.53               289.67               285.83
# Low                      288.35               283.89                278.2
# Close                     293.8               287.73               278.58
# Volume               4.5766e+07          3.43202e+07          2.72586e+07
# Dividend                      0                    0                    0
# Split                         1                    1                    1
# Adj_Open                289.195              283.979              284.328
# Adj_High                293.753              288.906              285.076
# Adj_Low                  287.59              283.141              277.466
# Adj_Close               293.025              286.971              277.845
# Adj_Volume           4.5766e+07          3.43202e+07          2.72586e+07
# Ticker                     AAPL                 AAPL                 AAPL
# Datetime    2020-04-30 00:00:00  2020-04-29 00:00:00  2020-04-28 00:00:00
#
#                            9     ...                 9925  \
# Date                 2020-04-27  ...           1980-12-26
# Open                      281.8  ...                 35.5
# High                     284.54  ...                35.62
# Low                      279.95  ...                 35.5
# Close                    283.17  ...                 35.5
# Volume              2.92055e+07  ...               248100
# Dividend                      0  ...                    0
# Split                         1  ...                    1
# Adj_Open                281.057  ...             0.502241
# Adj_High                 283.79  ...             0.503939
# Adj_Low                 279.212  ...             0.502241
# Adj_Close               282.423  ...             0.502241
# Adj_Volume          2.92055e+07  ...          1.38936e+07
# Ticker                     AAPL  ...                 AAPL
# Datetime    2020-04-27 00:00:00  ...  1980-12-26 00:00:00
#
#                            9926                 9927                 9928  \
# Date                 1980-12-24           1980-12-23           1980-12-22
# Open                       32.5                30.88                29.63
# High                      32.63                   31                29.75
# Low                        32.5                30.88                29.63
# Close                      32.5                30.88                29.63
# Volume                   214300               209600               166800
# Dividend                      0                    0                    0
# Split                         1                    1                    1
# Adj_Open               0.459798             0.436879             0.419194
# Adj_High               0.461637             0.438576             0.420892
# Adj_Low                0.459798             0.436879             0.419194
# Adj_Close              0.459798             0.436879             0.419194
# Adj_Volume          1.20008e+07          1.17376e+07           9.3408e+06
# Ticker                     AAPL                 AAPL                 AAPL
# Datetime    1980-12-24 00:00:00  1980-12-23 00:00:00  1980-12-22 00:00:00
#
#                            9929                 9930                 9931  \
# Date                 1980-12-19           1980-12-18           1980-12-17
# Open                      28.25                26.63                25.87
# High                      28.38                26.75                   26
# Low                       28.25                26.63                25.87
# Close                     28.25                26.63                25.87
# Volume                   217100               327900               385900
# Dividend                      0                    0                    0
# Split                         1                    1                    1
# Adj_Open                0.39967             0.376751             0.365999
# Adj_High                0.40151             0.378449             0.367838
# Adj_Low                 0.39967             0.376751             0.365999
# Adj_Close               0.39967             0.376751             0.365999
# Adj_Volume          1.21576e+07          1.83624e+07          2.16104e+07
# Ticker                     AAPL                 AAPL                 AAPL
# Datetime    1980-12-19 00:00:00  1980-12-18 00:00:00  1980-12-17 00:00:00
#
#                            9932                 9933                 9934
# Date                 1980-12-16           1980-12-15           1980-12-12
# Open                      25.37                27.38                28.75
# High                      25.37                27.38                28.87
# Low                       25.25                27.25                28.75
# Close                     25.25                27.25                28.75
# Volume                   472000               785200           2.0939e+06
# Dividend                      0                    0                    0
# Split                         1                    1                    1
# Adj_Open               0.358925             0.387362             0.406744
# Adj_High               0.358925             0.387362             0.408442
# Adj_Low                0.357228             0.385523             0.406744
# Adj_Close              0.357228             0.385523             0.406744
# Adj_Volume           2.6432e+07          4.39712e+07          1.17258e+08
# Ticker                     AAPL                 AAPL                 AAPL
# Datetime    1980-12-16 00:00:00  1980-12-15 00:00:00  1980-12-12 00:00:00
#
# [15 rows x 9935 columns]

# %%
missing = pd.concat([bigframe.isnull().sum(), 100 * bigframe.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#             count    %
# Date            0  0.0
# Open            0  0.0
# High            0  0.0
# Low             0  0.0
# Close           0  0.0
# Volume          0  0.0
# Dividend        0  0.0
# Split           0  0.0
# Adj_Open        0  0.0
# Adj_High        0  0.0
# Adj_Low         0  0.0
# Adj_Close       0  0.0
# Adj_Volume      0  0.0
# Ticker          0  0.0
# Datetime        0  0.0

# %%
bigframe.select_dtypes('object')
# Out:
#               Date Ticker
# 0       2020-05-08   AAPL
# 1       2020-05-07   AAPL
# 2       2020-05-06   AAPL
# 3       2020-05-05   AAPL
# 4       2020-05-04   AAPL
# ...            ...    ...
# 372120  1970-01-08    XOM
# 372121  1970-01-07    XOM
# 372122  1970-01-06    XOM
# 372123  1970-01-05    XOM
# 372124  1970-01-02    XOM
#
# [372125 rows x 2 columns]

# %%
bigframe['Ticker'].value_counts().head()
# Out:
# BA     14689
# CVX    12702
# XOM    12702
# IBM    12702
# F      12090
# Name: Ticker, dtype: int64

# %%
plt = bigframe.Ticker.value_counts().plot(kind='barh', figsize = (100, 80))
plt.set_title('Ticker')
plt.set_xlabel('Count')
plt
